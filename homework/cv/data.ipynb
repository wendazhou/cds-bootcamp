# %%
import torchvision

# %%
# Load dataset
ds = torchvision.datasets.Places365('/places365', small=True)

# %%
# Display first image
img, label = ds[0]
display(img)

# %%
# Write code to get total number of images
